# %% [markdown]
# # Prompt Engineering: Use OpenAI to Analyze Twitter Data
# This is a simple tutorial teaching prompt engineering basics and analyzing Twitter data with OpenAI large language models (LLM).
# Please purchase an [OpenAI API](https://openai.com/index/openai-api/) and store it in a safe place. This tutorial uses [AWS Secretes Manager](https://aws.amazon.com/secrets-manager/) to store the API keys.

# %% [markdown]
# ## Large Language Model Basics
# LLM repeatable predicts the next world using supervised learning. To predict the following sentence:
#
# `Learning data science in the cloud with AI`
#
# A model needs to learn to predict the following steps:
#
# |Input|Output|
# |:---|---|
# |Learning data science |in |
# |Learning data science in |the |
# |Learning data science in the |cloud |
# |Learning data science in the cloud |with |
# |Learning data science in the cloud with |AI|
#
# To train an LLM model:
# 1. Training a base LLM model on a large amount of training data to predict the next word
# 2. Fine-tune on examples where outputs follow instructions in the input
# 3. Human rates quality of different LLM outputs
# 4. Tune LLM to generate outputs with higher rates using RLHF (Reinforcement learning from human feedback)

# %% [markdown]
# ## Set up OpenAI Models

# %% [markdown]
# Load the API keys with AWS Secrets Manage Function

# %%
import boto3
from botocore.exceptions import ClientError
import json

def get_secret(secret_name):
    region_name = "us-east-1"

    # Create a Secrets Manager client
    session = boto3.session.Session()
    client = session.client(
        service_name='secretsmanager',
        region_name=region_name
    )

    try:
        get_secret_value_response = client.get_secret_value(
            SecretId=secret_name
        )
    except ClientError as e:
        raise e

    secret = get_secret_value_response['SecretString']
    
    return json.loads(secret)

# %% [markdown]
# ## Install Python libraries.
#
# - pymongo: manage the MongoDB database
# - openai: call the OpenAI APIs.

# %%
pip install openai
# Out:
# Collecting openai
#   Downloading openai-1.70.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from openai) (4.8.0)
# Collecting distro<2,>=1.7.0 (from openai)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from openai) (0.28.1)
# Collecting jiter<1,>=0.4.0 (from openai)
#   Downloading jiter-0.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from openai) (2.10.6)
# Requirement already satisfied: sniffio in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from openai) (4.12.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: idna>=2.8 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (2.27.2)
# Downloading openai-1.70.0-py3-none-any.whl (599 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 599.1/599.1 kB 30.7 MB/s eta 0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading jiter-0.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (352 kB)
# Installing collected packages: jiter, distro, openai
# Successfully installed distro-1.9.0 jiter-0.9.0 openai-1.70.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.11.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Downloading pymongo-4.11.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 72.7 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.7.0 pymongo-4.11.3
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Load the OpenAI API key and define a `openai_help` function.

# %%
from openai import OpenAI

openai_api_key  = get_secret('openai')['api_key']
client = OpenAI(api_key=openai_api_key)
model = 'gpt-4o'
temperature = 0

def openai_help(messages, model=model, temperature =temperature ):
    messages = messages
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=temperature

    )
    return response.choices[0].message.content

# %% [markdown]
# Temperature:
# - Low temperature: always choose the most likely response, reliable, predictable responses
# - High temperature: diverse responses, more creative responses
#
# Tokens and Models:
# - LLM predicts tokens, which are commonly occurring sequences of characters.
# - One token is about four characters in English, and 100 tokens are roughly 75 words. Check [token estimate](https://platform.openai.com/tokenizer).
# - Different models can process various amounts of tokens at different performance levels and costs. Check [OpenAI models](https://platform.openai.com/docs/models) for more details.
#
# Roles:
# - system: specify the overall tone or behavior of the assistant
# - user: instruction given to the LLM
# - assistant: LLM responded content, we also can provide content in few-shot promoting or histories of conversations

# %% [markdown]
# A simple example using [gtp-4o](https://platform.openai.com/docs/models/gpt-4o) and temperature 0.

# %%
messages = [{"role": "user", "content": "What is the capital of USA"}]

print(openai_help(messages))
# Out:
# The capital of the United States is Washington, D.C.

# %% [markdown]
# Add a system message asking LLM to act as a high school teacher with different temperatures.

# %%
messages = [
    {"role": "system", "content": "use tone as a high school teacher"},
    {"role": "user", "content": "What is the capital of USA"}
    ]

print(openai_help(messages, temperature = 0.8))
# Out:
# The capital of the United States is Washington, D.C. It's important for everyone to remember key facts like this, especially when discussing topics related to geography or current events. If anyone needs more information about Washington, D.C., feel free to ask!

# %% [markdown]
# Add assistant messages to teach LLM what `##` is.

# %%
messages = [
    {"role": "user", "content": "What is 1##1"},
    {"role": "assistant", "content": "it is 11"},
    {"role": "user", "content": "What is 2##2"},
    {"role": "assistant", "content": "it is 22"},
    {"role": "user", "content": "What is 3##3"},
    ]
print(openai_help(messages))
# Out:
# It is 33.

# %% [markdown]
# ## Prompt Engineering Principles
# - Use delimiters to separate different parts of a prompt to provide clear instructions and prevent prompt injections.
# - Structure outputs in JSON documents or other formats to use the outputs in subsequent steps
# - Few-shot promoting: provide successful examples of a task and then ask the model to perform a similar task.
# - Chain of thought reasoning: request a series of reasoning steps in prompts to help the model achieve correct answers
# - Chain of prompts: split a task into multiple prompts where each prompt can focus on a sub-task at a time and take different actions at different stages. It saves tokens, is easier to test, can involve human input, or use external tools.
# - Interactive process
#   1. Try something first
#   2. Analyses the result, identify errors, and redefine the prompt
#   3. Test the prompts with different datasets

# %% [markdown]
# An example using delimiters, structured output and few-shot promoting:

# %%
delimiter = '###'
sentence1 = 'I love cat.'
sentence2 = 'I love dog.'
messages = [
    {"role": "system", "content": f"""analyze the sentiment in a sentence delimitered by {delimiter},
                                     return the result as a JSON document"""},
    {"role": "user", "content": f"{delimiter}{sentence1}{delimiter}"},
    {"role": "assistant", "content": "{sentiment:positive}"},
    {"role": "user", "content": f"{delimiter}{sentence2}{delimiter}"}
    ]

print(openai_help(messages))
# Out:
# { "sentiment": "positive" }

# %% [markdown]
# ## Analyze Twitter data

# %% [markdown]
# ### Connect to the MongoDB cluster

# %%
import pymongo
from pymongo import MongoClient
mongodb_connect = get_secret('mongodb')['connection_string']

mongo_client = MongoClient(mongodb_connect)
db = mongo_client.demo # use or create a database named demo
tweet_collection = db.tweet_collection #use or create a collection named tweet_collection
tweet_collection.create_index([("tweet.id", pymongo.ASCENDING)],unique = True) # make sure the collected tweets are unique
# Out:
# 'tweet.id_1'

# %% [markdown]
# ### Extract Tweets

# %%
filter={

    
}
project={
    'tweet.text': 1, 
    'tweet.id': 1
}
#rename the client to mongo_client
result = mongo_client['demo']['tweet_collection'].find(
  filter=filter,
  projection=project
)

# %%
tweet_data = []
for tweet in result:
    tweet_data.append(tweet['tweet']['text'])

# %%
print('Number of tweets: ',len(tweet_data))
# Out:
# Number of tweets:  299

# %% [markdown]
# ### Summarization
# - Analyze election tweets with delimiters
# - Change the size of the summarization
# - Summarize tweets and focus on different perspectives.

# %%
messages = [
    {"role": "system", "content": f"""provide a brief summary of the tweets delimited by {delimiter}"""},
    {"role": "user", "content": f"{delimiter}{tweet_data}{delimiter}"},
    ]

print(openai_help(messages))
# Out:
# The tweets cover a wide range of topics related to elections and political events. Key themes include concerns about election integrity, with accusations of potential election interference and fraud, particularly involving the GOP and Democrats. There are discussions about voter ID laws, early voting, and the importance of high voter turnout. Some tweets focus on specific political figures, such as Donald Trump, Kamala Harris, and Joe Biden, with opinions on their actions and potential election outcomes. International politics are also mentioned, with references to geopolitical tensions and alliances. Additionally, there are tweets about media coverage and its influence on public perception, as well as discussions on cryptocurrency and its potential impact on elections. Overall, the tweets reflect a mix of political opinions, predictions, and concerns leading up to upcoming elections.

# %%
messages = [
    {"role": "system", "content": f"""provide a brief summary of the tweets delimited by {delimiter},
                                    limit the summary to 20 words"""},
    {"role": "user", "content": f"{delimiter}{tweet_data}{delimiter}"},
    ]

print(openai_help(messages))
# Out:
# The tweets discuss election-related controversies, including conspiracy theories, voter ID laws, media bias, and potential election interference. Concerns about Trump and Kamala Harris are prominent.

# %%
messages = [
    {"role": "system", "content": f"""provide a brief summary of the tweets delimited by {delimiter},
                                    focus on how people discuss AI,
                                    limit the summary to 50 words"""},
    {"role": "user", "content": f"{delimiter}{tweet_data}{delimiter}"},
    ]

print(openai_help(messages))
# Out:
# The tweets primarily focus on election-related discussions, with minimal mention of AI. AI is not a central topic in these tweets, as they are more concerned with political events, election integrity, and various opinions on candidates and election outcomes.

# %% [markdown]
# ### Moderation
# - Iterate each tweet and use the [moeration endpoint](https://platform.openai.com/docs/api-reference/moderations) to identify flagged tweets
# - Print flagged tweets

# %%
def flag_help(tweet):
    response = client.moderations.create(
        model="omni-moderation-latest",
        input=tweet)

    if response.results[0].flagged:
        print('===')
        cat_dict = response.results[0].categories.to_dict()
        for cat in cat_dict.keys():
            if cat_dict.get(cat):
                print (cat)
                print(tweet)

# %%
for tweet in tweet_data:
    flag_help(tweet)
# Out:
# ===
# harassment
# @DC_Draino Kamala let in a bunch of terrorist! DHS caught one planning an attack on election day! He was in oklahoma of all places! They are everywhere!
# ===
# harassment
# The media and the left spend all year claiming crime is down. They “fact check” Trump at the debate on it. Weeks before the election, the FBI quietly “updates” the data to show that crime is in fact up. The leftist response is to say “relax, rightoid, the FBI does this REGULARLY”
# ===
# harassment
# @LauraLoomer Their time will be coming to an end soon once Trump wins this election. They will be running and hiding. No more protection from this treasonous administration.
# ===
# harassment
# @BretBaier This will be the biggest pillow fight of the election process. She was indeed the Border Czar, she lied to us about the health of President Biden, used tax payer $ to pay for a convicted felons sex change,  no wars when Trump was President and what is her position on the freedom… https://t.co/PEgwpFAM5q
# ===
# violence
# RT @ecomarxi: Biden/Harris [during a full year of genocide &amp; overwhelming domestic &amp; international pressure to embargo Israel]: We will NEV…
# ===
# harassment
# RT @maddenifico: Some of you self-righteous motherfuckers on the left are once again overthinking this. It's as if you faux-prog frauds lea…
# ===
# harassment
# RT @Starboy2079: Why BJP doesn't understand a simple fact that as number of Bangladeshi Muslims and Rohingyas will keep increasing, their p…
# ===
# violence
# RT @ecomarxi: “There’s an election in three weeks. We might lose because we’re committing genocide.”
#
# “I know! Let’s promise to do what we…
# ===
# harassment
# RT @TheRickyDavila: Corrupt GOP scumbag James Comer basically went on propaganda outlet newsmax to say the biggest irregularity in the 2020…
# ===
# violence
# RT @democracynow: Uncommitted Co-Founder Abbas Alawieh on U.S. Election &amp; Family in Lebanon Fleeing Israeli Bombs https://t.co/f00eSotc84
# ===
# harassment
# RT @caslernoel: Never lose sight of what a clownish little man Mike Johnson is and how he ALREADY worked on behalf of Trump’s attempts at o…
# ===
# violence
# RT @nypost: Israel is ready to strike Iran — with attack expected before US election: report https://t.co/RchKtyTXLx https://t.co/1rtK5EFz9C
# ===
# harassment
# @SebGorka What the hell do this lady be talking about? I have never heard anybody from Russia talking about her or this election. I just don't like your fake ass. I never liked her from the moment She came forward as vice president lol her spirit seems fake and sinister
# ===
# harassment
# @RepSwalwell Your desperation is hilarious.  Election night will even be funnier.
# ===
# harassment
# @PettyLupone @Bobbysworld2021 You people are liars and pathetic human beings. There’s a reason you’re going to lose this election and the next one and the next one. You’re weak humans that no sane person wants to follow.
# ===
# harassment
# RT @Michell33650674: ELON MUSK IS A PRIVATE CITIZEN WHO JUST OPENLY TRIED TO PURCHASE AN ELECTION.  WHY THE FUCK HAVEN'T STATE OFFICIALS AR…
# ===
# harassment
# RT @JDVanceNewsX: Do you support President Trump invoking The Alien Enemies Act of 1798 to SPEED UP deportations of CRIMINAL illegals?
#
# A.…
# ===
# violence
# RT @bennyjohnson: 🚨Julie Kelly Calls For President Trump to REOPEN The Case Into Ashli Babbit's Murderer Michael Byrd, It Was Covered Up:…
# ===
# harassment
# RT @maddenifico: Due to untrustworthy drunks and assclowns like Defense Secretary Pete Hegseth and National Security Advisor Mike Waltz, Ir…
# ===
# harassment
# @gemmadurany Maduro és comparable a Trump en la falta de respecte a la llei. A Itàlia governa Meloni i a Macron no li convé aquest escàndol. El problema és que els jutges francesos són mentalment tan quadrats com els alemanys. O fins i tot més.
# ===
# harassment
# RT @kylenabecker: JUST IN: The Trump administration defies rogue Judge James Boasberg and deports MORE Trens de Aragua and MS-13 gang membe…
# ===
# violence
# RT @eduardomenoni: 🚨| ÚLTIMA HORA: DURÍSIMO GOLPE AL TIRANO NICOLÁS MADURO Y A SU SOCIO, PEDRO SÁNCHEZ. Repsol cae más de 2,6% en Bolsa tra…
# ===
# harassment
# RT @SkylineReport: So Trump handed his own fucking company a tariff exemption? Must be fucking nice to rig the system in your favor while s…
# ===
# violence
# RT @ClownWorld_: BREAKING: 70-year-old Christopher Talbot has been arrested after plowing his car into a Trump supporter outside a Tesla de…
# ===
# harassment
# @Matthewtravis08 Fact: Obama, the deported in chief. Yay that's great. Trump the next deported in chief. Fascist! 🙄
# ===
# harassment
# @endofamalek @hutchinson I agree, which is why we have a justice system to punish those who fraudulently seek asylum. So why isn't Trump sending these evil gang members though that system?
#
# Be specific.
# ===
# harassment
# RT @JDVanceNewsX: Do you support President Trump invoking The Alien Enemies Act of 1798 to SPEED UP deportations of CRIMINAL illegals?
#
# A.…
# ===
# harassment
# @WatcherGuru they see Trump getting weaker by the day due to his own idiocy and ego.
# ===
# harassment
# RT @Kathy773301832: @iAnonPatriot If these people would wake up! Trump &amp; Elon are working at lightning speed!
#
# Ridiculous liberal lunatics…
# hate
# RT @Kathy773301832: @iAnonPatriot If these people would wake up! Trump &amp; Elon are working at lightning speed!
#
# Ridiculous liberal lunatics…
# ===
# harassment
# RT @Michell33650674: ELON MUSK IS A PRIVATE CITIZEN WHO JUST OPENLY TRIED TO PURCHASE AN ELECTION.  WHY THE FUCK HAVEN'T STATE OFFICIALS AR…
# ===
# violence
# RT @TheCalvinCooli1: 🚨New: President Trump has announced that the Houthi terrorists have been destroyed https://t.co/h7rWjVnBki
# ===
# violence
# Trump ameaça Putin com novas sanções se derramamento de sangue na Ucrânia continuar https://t.co/smKGNVvBlg
# ===
# harassment
# … “NATO” is a Cover-Organization because USA took Russian Royal Family as Prisoners (not realizing they were Kidnapped to begin with . )
# …. PART of “Collapse of USSR” delta with Not Murdering said Hostages (Trump Organization of course welched on this . -
# …. Neil invents NEW w
# violence
# … “NATO” is a Cover-Organization because USA took Russian Royal Family as Prisoners (not realizing they were Kidnapped to begin with . )
# …. PART of “Collapse of USSR” delta with Not Murdering said Hostages (Trump Organization of course welched on this . -
# …. Neil invents NEW w
# ===
# harassment
# @krassenstein @realDonaldTrump They were ordered deported by judges. Do you think Trump would get away with violating the law and his oath? MAGA would never stand for that and he knows it. He does what we say because in a Democracy the voters are the dictators. We don't bow down to our leaders like you do.
# ===
# harassment
# @KarluskaP Nah.  It's a tired old metaphor.   Trump carries the weight of nothing on his shoulders and there is nothing for him to shrug off.   He has abdicated his role as a world leader in favor of golf-ball diplomacy from the safety of our shores.   Still he wishes for a moat like the UK
# ===
# harassment
# RT @FlaviaMSoares76: A pessoa abre a porra do esgoto da boca dela pra dizer que o Xandao está certo em me censurar porque estou em outro pa…
# ===
# harassment
# RT @maddenifico: Great "Canada Strong" commercial by PM Mark Carney and Mike Myers. Fuck Trump, fuck Elon Musk, fuck fascism and fuck Nazis…

# %% [markdown]
# ### Transforming
# - Translating to a different language
# - Transform tones, such as formal vs. informal.

# %%
for tweet in tweet_data:
    messages = [
        {"role": "system", "content": f"""translate the tweets delimited by {delimiter} into Chinese"""},
        {"role": "user", "content": f"{delimiter}{tweet}{delimiter} "}]

    print(openai_help(messages).strip(delimiter))
# Out:
# “颠覆选举”：监察组织警告共和党利用法院“洗白阴谋论” https://t.co/9VkgMa6SV3
# @DC_Draino 卡玛拉放进了一群恐怖分子！国土安全部抓住了一个计划在选举日发动袭击的人！他居然在俄克拉荷马！他们无处不在！
# @ssecijak 我们必须以压倒性的数量出现，以毫无疑问地表明谁赢得了这次选举。
# RT @GlennYoungkin: 对我来说，令人难以置信的是，就在总统选举前25天，司法部正在起诉联邦政府以执行……
# RT @newrepublic: 泄露的电子邮件揭示了Rasmussen Reports的真相，以及特朗普竞选团队如何违反选举法。
#
# https://t…
# @NickGarzilli @BruneElections @SMCosta6 @tencor_7144 波多黎各只是为了进行人工计票。在选举之夜，投票站工作人员会统计州长、参议员、州代表、市长和镇议会代表的选票。平均来说，有120万张选票。现在，他们已经转向电子（Dominion）计票，并出现了计票问题。
# 🇺🇸🚨 我们正在前往默瑟县选举委员会的路上...
#
# 显然，那里的一个无家可归居民被拒绝注册为选民，这在宾夕法尼亚州是非法的。
#
# 今晚我们将和平地参加那里的选举委员会听证会，以表达我们的不满。
# RT @PATRICKHENRY97: 那么，为什么自由派不希望投票需要身份证？哦，我知道他们再也不会赢得选举。身份证和一天投票。L…
# 媒体和左派整年都在声称犯罪率下降。他们在辩论中对特朗普的说法进行“事实核查”。在选举前几周，FBI悄悄“更新”数据，显示犯罪率实际上在上升。左派的回应是说“放轻松，右派，FBI经常这样做”
# 在他们的选举报道节目中，India Today 将埃克纳特·辛德描绘为马拉塔士兵，而乌达夫·萨克雷则被描绘为莫卧儿士兵。
#
# 也许这是一个弗洛伊德式的失误，或者可能是故意的，但似乎 India Today 这次准确地把握了基层的情绪。https://t.co/LiXvIYzSYI
# 如果唐纳德·特朗普赢得选举，有两种可能的情况：
#
# 1. 加密货币市场因我们终于有了一位支持加密货币的总统而上涨。
#
# 2. 市场出现小幅下跌，“买传闻，卖新闻”。
#
# 从长远来看，无论谁是总统都完全无关紧要，因为加密货币是…… https://t.co/8hqZ5YNQmQ
# @EndWokeness 所以现在我们可以期待在这次选举中有13,001张来自已故者的选票吗？
# RT @Craptld2kids: 只是提醒一下他们四年前对我们做了什么。当他们在11月5日的选举中失利时，要准备好应对更多的恶作剧。ht…
# RT @django: 对于任何对选举感到焦虑的人，深呼吸一下，记住，无论谁赢，美国的生活都会继续变得更好……
# 关于2024年选举的民意调查 | 与Greg St的对话... https://t.co/qfj25AILml 通过 @YouTube
# RT @OccupyDemocrats: 最新消息：MAGA遭受重创，佐治亚州一名法官裁定县选举官员不得推迟或拒绝…
# RT @VigilantFox: 关于即将到来的选举有些不对劲，感觉民主党计划窃取选举。
#
# “今天在乔治亚州…
# @LauraLoomer 一旦特朗普赢得这次选举，他们的时代就要结束了。他们将会逃跑和躲藏。这个叛国政府将不再保护他们。
# RT @OccupyDemocrats: 突发新闻：唐纳德·特朗普在荒谬地声称权力和平移交后，被采访者羞辱…
# @BretBaier 这将是选举过程中最大的枕头大战。她确实是边境沙皇，她对我们撒谎关于拜登总统的健康状况，用纳税人的钱为一名被定罪的重犯支付变性手术费用，特朗普当总统时没有战争，她对自由的立场是什么… https://t.co/PEgwpFAM5q
# 你不能引用你的偶像毛泽东的话吗，还是你会搞砸选举？https://t.co/W6fuRj0b2k https://t.co/UBzwK0mMUq
# @DustieDahl @KathleenWinche3 在任何州，非公民在联邦选举中注册或投票都是不合法的。
#
# 少撒谎。
# 转发 @MargieVotes: #民主党团结 #自豪的蓝色
# 随着我们接近2024年选举，我们必须发声。
#
# 我知道我们很累。选举就在几周后……
# RT @whstancil: 生活在摇摆州的人们：我们正被右翼虚假信息淹没。所有大型国家媒体都拒绝报道……
# FBI发布虚假的犯罪统计数据，然后媒体使用这些虚假数据在辩论中对特朗普进行“事实核查”，而实际上他在说真话？这就是FBI和新闻媒体的实际选举干预。这是叛国。这是反美。这是战争。
# 重要信息：来自@SimonWDC的Hopium Chronicles子刊今天的内容：“要注意2024年红色浪潮努力的规模。它远比2022年更大，并且包括像Polymarket和Elon这样的新参与者。他们正在努力制造一种选举正在失去的印象…… https://t.co/7At7SvhOaM
# @joshtheobald3 我们必须这样做，因为我妻子在选举日要上班，她下班太晚赶不上投票，所以我们会在21号投票。
# 特朗普现在有60%的几率赢得总统选举！
#
# $TRUMP https://t.co/tKsvcWn5QP
# @ScottPresler 看起来很奇怪，Thad Hall 在2020年选举期间在亚利桑那州工作。他是否因为在亚利桑那州为拜登赢得选票而获得晋升到宾夕法尼亚州？让人不禁思考的事情
# @CentristMadness 因为没有其他人了解它们的运作方式或真正关心
#
# 这就是我们应得的选举和媒体环境
# RT @ecomarxi: 拜登/哈里斯[在经历了一整年的种族灭绝以及国内外要求对以色列实施禁运的巨大压力下]：我们绝不会…
# .@dYdX 推出了特朗普永续预测市场 (TRUMPWIN-USD)，您可以在特朗普的选举机会中做多或做空，杠杆高达20倍。提供高级订单类型、专业图表和完全去中心化。别人预测，你来交易;) 👉… https://t.co/JZlC8oKiEP
# 阅读底部的字幕
#
# 我祈祷他也能活到参加2028年的选举
# 这是一个拥有坚定决心的虔诚之人 https://t.co/WvI9ewX6n1
# @MarioNawfal 是时候让更多的声音在即将到来的选举中被听到了，而不是那些已经去世却仍然能够投票的人！
# RT @DanRShafer: 这个超级政治行动委员会一直在使用这些资金反对塔米·鲍德温。
#
# 而这笔捐款使得乌伊莱恩家族在这次选举中的支出达到了……
# @C_Farthammer 那个胖乎乎的妖精在2020年大选结果决定之前就宣布了亚利桑那州。福克斯新闻和CNN没什么两样。
# RT @Iam_Rohit_G: 印度人民党结束了布彭德拉·胡达在哈里亚纳邦的政治生涯。
#
# 印度人民党将结束沙拉德·帕瓦尔在马哈拉施特拉邦的政治生涯。
#
# T…
# RT @themarketswork: 把一个行动不便的百岁老人推出来为卡玛拉投票是对民主党选举诚信方法的隐喻。
# RT @BradBeauregardJ: 这位来自宾夕法尼亚州的86岁老人说，2024年的这次选举是他一生中最重要的选举…
# https://t.co/dWyL7zpadU
# 11月5日的总统选举可能在宾夕法尼亚州决定胜负，最近在该州关键社区进行的Cygnal民调显示，唐纳德·特朗普可能处于领先地位。
# 🔍🔒 透明与安全相遇
#
# 📊 在这个网络安全意识月，我们自豪地推出增强投票的选举结果平台，提供100%正常运行时间和实时更新。我们的平台允许选民通过互动地图和图表进行参与，确保透明度… https://t.co/v14acBW6KL https://t.co/N1dqDL78y1
# @christianboutin @scrowder 他们正在推动这些虚假的民意调查，显示特朗普大幅领先，以便在卡玛拉在十一月以压倒性优势获胜时声称选举舞弊
# 转发@michaelsbarajas：一位德克萨斯州的警长将在下个月的选票上，他似乎违反了州法律中关于警长如何调查的规定……
# RT @RealMattCouch: 这太疯狂了。这是媒体公然的选举干预，他们必须被特朗普司法部起诉。
# RT @SimonWDC: 昨晚特朗普在镜头前迷失了方向，整整39分钟。观看视频，令人震惊。
#
# 他的执政能力，…
# 转发 @FrankLuntz: 来自 @NPR 的报道：“唐纳德·特朗普似乎再次在这次总统选举中处于主导地位。
#
# 当我们观察……”
# RT @maddenifico: 你们这些自以为是的左派混蛋又一次想得太多了。就好像你们这些伪进步的骗子从来没有学到过教训一样……
# 我妈妈在2016年选举日时无法投票，2020年因为疫情，他们没有派特别选举官员到她所在的设施，所以这是她第一次有机会投票反对特朗普，她对此感到非常兴奋。
# RT @LibertyLockPod: 我坚信这个人和其他50名签署“笔记本电脑信”的前情报人员应该……
# RT @WalshFreedom: 卡玛拉·哈里斯终于对特朗普发起攻击，早该如此了！
#
# 如果他被正常化，他就会赢。他不正常——他是个骗子……
# RT @mtgreenee: 乔治亚州的女性们充满激情，准备投票！
#
# 她们担心孩子们的未来和家庭的安全。
#
# 预…
# 迫不及待地想让这次选举结束。
# 选举入门视频 为什么你需要投票给@realDonaldTrump https://t.co/WVpKGOwZlm
# RT @shaun_vids: 选举之后，他们可以在不实际阻止内塔尼亚胡的情况下，以对他强硬的姿态参选。真是玩世不恭，邪恶的…
# @CristusVictor 我在这里到处都能看到这种变化，唯一不合时宜的是高地位的媒体仍然为许多人定义什么是真实/虚幻、对/错。也许这次选举结束后会进一步打破这种局面。
# RT @MTGrepp: 天啊 🚨 这位纽约人在接受记者采访时毫不留情。我们需要更多这样的声音
#
# “如果你们再试一次……”
# 转发 @RonFilipkowski: 传统媒体对这次选举的报道简直是一团糟，他们慢慢地把我们引向独裁。“即兴音乐会。” 🖕…
# @Lucas_FCGB 您可以亲自申请和投递邮寄选票。
#
# https://t.co/cYiPpFttpT
# 转发 @NickJFuentes: 特朗普2024： • 大规模移民（合法） • 跨性别儿童（需父母同意） • 不发动新战争（除了与伊朗） • 免费…
# RT @AccountableGOP: 乔治亚州前共和党副州长@GeoffDuncanGA 谈到唐纳德·特朗普：“他天生就是个骗子……因为他没有赢得胜利，并且因为……”
# RT @MTGrepp: 突发新闻 🚨 唐纳德·特朗普刚刚揭露了司法部的选举干预行为 🔥
#
# “弗吉尼亚清理了其选民名册…”
# RT @mariashriver: 我知道现在有很多关于选举的焦虑。我知道这场竞选很接近，但副总统@KamalaHarris仍然…
# 加利福尼亚州居民可以在10月21日之前在线注册，以参加11月5日的选举。请在以下网址查看您的选民状态或注册：https://t.co/DuBK9nYqI3 https://t.co/lgCri2T6W5
# RT @Starboy2079: 为什么印度人民党不明白一个简单的事实，即随着孟加拉国穆斯林和罗兴亚人的数量不断增加，他们的政…
# @glassfire77 @0xMikado 是的，我理解——2016年和2020年的民调在某些州非常不准确。2022年也是如此——但方向相反。自从罗伊案被推翻以来的每次选举都低估了对民主党的支持——几乎每次都是。我们拭目以待……
#
# （顺便说一下——到目前为止，宾夕法尼亚州的提前投票对民主党来说非常有利）
# 抱歉，我无法协助翻译该内容。
# RT @BehizyTweets: 乔治亚州最腐败的法官之一刚刚裁定，即使存在欺诈或系统问题，选举官员也必须认证结果…
# @nancyd1957 @sdduba 候选人竞选总统不再需要赢得初选的先例是否也让你感到担忧？
# RT @ScottPresler: 致我们的自由意志主义者，我们希望得到你们的选票。这是一次支持和平、反对战争的选举。
#
# 致我们的RFK Jr.支持者，我们希望你们的……
# RT @SteveLovesAmmo: 砰！！！🔥💥
#
# 唐纳德·特朗普在Polymarket的赔率中领先19.6个百分点，有望赢得2024年大选。
#
# 这完全打破了……
# RT @BrendanKeefe: 最新消息：乔治亚州在提前投票的第一天打破了投票记录 @ATLNewsFirst
# https://t.co/YjisV01X26 https://t.co…
# @AmazingZoltan 立即举行选举，否则我们将彻底毁灭！
# RT @DefiyantlyFree: 只要民主党反对选民身份证法、清理选民名单以及验证只有公民才能投票，我就会…
# RT @ecomarxi: “三周后有选举。我们可能会因为犯下种族灭绝罪而失败。”
#
# “我知道！让我们承诺去做我们……”
# RT @ghn_news: 美国在全球健康领域的领导地位的未来悬于此次选举的平衡，这对候选人提出了紧迫的要求……
# 我对任何选举的三个主要关注点与我对政府的三个主要关注点始终如一——基础设施、教育和医疗保健。其他一切都是次要的。
# @GuntherEagleman 我不知道，当她赢得选举时你会离开吗？
# RT @wiley_inc: @EdanClay 让我提醒你
#
# 1) 民意调查是短暂的
# 2) 民意调查数量众多
# 3) 民意调查没有预测价值
# 4) 民意调查各不相同,…
# RT @TheRickyDavila: 腐败的共和党混蛋詹姆斯·科默基本上是在宣传媒体Newsmax上说2020年最大的违规行为是…
# RT @WesleyHuntTX: 巴拉克·奥巴马不会对我和其他黑人男性讲述如何在这次选举中投票。巴拉克·奥巴马并不住在……
# @onelerv @z388z @EricLDaugh 但这次选举的平均值是共和党。所以d+2看起来不对。Rausmusen用的是什么？或者看看那个Marquette民调，50-50。我相信那个平局的NBC民调使用了相同的党派身份，但它是注册选民。
#
# https://t.co/fqj8tQCDV4
# RT @BradBeauregardJ: 这位来自宾夕法尼亚的86岁老人说，2024年的这次选举是他一生中最重要的选举……
# 转发 @levparnas: 在选举前的接下来的20天里，我每天都会发布这个视频，以确保每个人都能清楚地看到 @rea 是谁…
# RT @BehizyTweets: 乔治亚州最腐败的法官之一刚刚裁定，即使存在欺诈或系统问题，选举官员也必须认证结果…
# RT @LangmanVince: @BretBaier @VP 坚决不看，自从你们帮助民主党窃取2020年大选后，我就再也没看过福克斯新闻，而且…
# RT @Real_RobN: 这里是，
#
# 2020年亚利桑那州参议院选举审计的官方结果，
#
# • +255,000张没有记录的提前投票…
# RT @DefiyantlyFree: 乔·罗根：即使你试图在谷歌上搜索，也找不到关于卡玛拉·哈里斯的负面新闻……
#
# 说实话，这看起来公平吗……
# RT @TristanSnell: 最新消息：乔治亚州法院裁定选举结果认证是强制性的——选举主管和成员……
# RT @TristanSnell: 最新消息：乔治亚州法院裁定选举结果认证是强制性的——选举主管和成员……
# RT @ChristruthJ: @Real_RobN 谢谢你..真正的罗伯特...展示了确凿的证据...亚利桑那州的选举被窃取了...我们需要展示这个并讨论…
# RT @MichelleObama: 乔治亚州！我很高兴能在10月29日星期二加入@WhenWeAllVote在亚特兰大举行的集会！
#
# 随着提前投票的进行…
# 选举伎俩 🤷🏾‍♂️ https://t.co/60VhB47cXA
# RT @hodgetwins: 如果这次选举是公正的，特朗普将赢得50个州
# RT @democracynow: 未承诺的联合创始人阿巴斯·阿拉维谈美国大选及其在黎巴嫩的家人逃离以色列的轰炸 https://t.co/f00eSotc84
# RT @MJTruthUltra: 他们又试图窃取乔治亚州的选举……腐败的乔治亚州法官称官员必须认证选举结果……
# RT @Conservative_BC: 这次选举与众不同。是时候尝试一些新的东西了。是时候进行常识性的改变了。#bcpoli
#
# 今天投票：ht…
# RT @Morning_Joe: “我从未见过这样的事情……24小时后，我仍然不知道发生了什么。在[选举]前三周……”
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 6
#       1 for tweet in tweet_data:
#       2     messages = [
#       3         {"role": "system", "content": f"""translate the tweets delimited by {delimiter} into Chinese"""},
#       4         {"role": "user", "content": f"{delimiter}{tweet}{delimiter} "}]
# ----> 6     print(openai_help(messages).strip(delimiter))
#
# Cell In[4], line 10, in openai_help(messages, model, temperature)
#       8 def openai_help(messages, model=model, temperature =temperature ):
#       9     messages = messages
# ---> 10     response = client.chat.completions.create(
#      11         model=model,
#      12         messages=messages,
#      13         temperature=temperature
#      14
#      15     )
#      16     return response.choices[0].message.content
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/openai/_utils/_utils.py:279, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     277             msg = f"Missing required argument: {quote(missing[0])}"
#     278     raise TypeError(msg)
# --> 279 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/openai/resources/chat/completions/completions.py:914, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, web_search_options, extra_headers, extra_query, extra_body, timeout)
#     871 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     872 def create(
#     873     self,
#    (...)
#     911     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     912 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     913     validate_response_format(response_format)
# --> 914     return self._post(
#     915         "/chat/completions",
#     916         body=maybe_transform(
#     917             {
#     918                 "messages": messages,
#     919                 "model": model,
#     920                 "audio": audio,
#     921                 "frequency_penalty": frequency_penalty,
#     922                 "function_call": function_call,
#     923                 "functions": functions,
#     924                 "logit_bias": logit_bias,
#     925                 "logprobs": logprobs,
#     926                 "max_completion_tokens": max_completion_tokens,
#     927                 "max_tokens": max_tokens,
#     928                 "metadata": metadata,
#     929                 "modalities": modalities,
#     930                 "n": n,
#     931                 "parallel_tool_calls": parallel_tool_calls,
#     932                 "prediction": prediction,
#     933                 "presence_penalty": presence_penalty,
#     934                 "reasoning_effort": reasoning_effort,
#     935                 "response_format": response_format,
#     936                 "seed": seed,
#     937                 "service_tier": service_tier,
#     938                 "stop": stop,
#     939                 "store": store,
#     940                 "stream": stream,
#     941                 "stream_options": stream_options,
#     942                 "temperature": temperature,
#     943                 "tool_choice": tool_choice,
#     944                 "tools": tools,
#     945                 "top_logprobs": top_logprobs,
#     946                 "top_p": top_p,
#     947                 "user": user,
#     948                 "web_search_options": web_search_options,
#     949             },
#     950             completion_create_params.CompletionCreateParams,
#     951         ),
#     952         options=make_request_options(
#     953             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     954         ),
#     955         cast_to=ChatCompletion,
#     956         stream=stream or False,
#     957         stream_cls=Stream[ChatCompletionChunk],
#     958     )
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/openai/_base_client.py:1242, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1228 def post(
#    1229     self,
#    1230     path: str,
#    (...)
#    1237     stream_cls: type[_StreamT] | None = None,
#    1238 ) -> ResponseT | _StreamT:
#    1239     opts = FinalRequestOptions.construct(
#    1240         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1241     )
# -> 1242     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/openai/_base_client.py:919, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     916 else:
#     917     retries_taken = 0
# --> 919 return self._request(
#     920     cast_to=cast_to,
#     921     options=options,
#     922     stream=stream,
#     923     stream_cls=stream_cls,
#     924     retries_taken=retries_taken,
#     925 )
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/openai/_base_client.py:955, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     952 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     954 try:
# --> 955     response = self._client.send(
#     956         request,
#     957         stream=stream or self._should_stream_response_body(request=request),
#     958         **kwargs,
#     959     )
#     960 except httpx.TimeoutException as err:
#     961     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File ~/anaconda3/envs/python3/lib/python3.10/ssl.py:1292, in SSLSocket.recv(self, buflen, flags)
#    1288     if flags != 0:
#    1289         raise ValueError(
#    1290             "non-zero flags not allowed in calls to recv() on %s" %
#    1291             self.__class__)
# -> 1292     return self.read(buflen)
#    1293 else:
#    1294     return super().recv(buflen, flags)
#
# File ~/anaconda3/envs/python3/lib/python3.10/ssl.py:1165, in SSLSocket.read(self, len, buffer)
#    1163         return self._sslobj.read(len, buffer)
#    1164     else:
# -> 1165         return self._sslobj.read(len)
#    1166 except SSLError as x:
#    1167     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
for tweet in tweet_data:
    messages = [
        {"role": "system", "content": f"""rewrite the tweets delimited by {delimiter} in the tone like Stewie """},
        {"role": "user", "content": f"{delimiter}{tweet}{delimiter} "}]

    print(openai_help(messages).strip(delimiter))
# Out:
# "Oh, how delightfully predictable! The GOP, those cunning little devils, are apparently attempting to 'subvert the election' by using the court as their personal laundromat for conspiracy theories. How droll! Do tell me more, I'm simply riveted." https://t.co/9VkgMa6SV3
# Oh, splendid! It appears Kamala has been playing a delightful game of "Let's Invite the Terrorists Over for Tea." And what a charming choice of location—Oklahoma, of all places! My, my, they do seem to be popping up like daisies, don't they?
# @ssecijak Oh, the audacity! We must assemble in such overwhelming numbers that even the most oblivious of simpletons will have no choice but to acknowledge our victory in this electoral charade.
# RT @GlennYoungkin: Oh, the audacity! Just 25 days before a presidential election, and the DOJ decides to sue the Commonwealth for enforcing... How delightfully absurd!
# Ah, delightful! It appears the curtain has been pulled back on the Rasmussen Reports, revealing a rather scandalous little dance with the Trump campaign. How utterly predictable. Do tell me more, I'm simply riveted.
# Oh, how delightfully primitive! In Puerto Rico, they used to count votes by hand, like some sort of quaint village fair. Imagine, poll workers tallying up votes for governors, senators, and the like, all by candlelight, I presume. But now, they've embraced the modern age with electronic voting systems, and what do you know? They've encountered a few hiccups. How utterly predictable.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 6
#       1 for tweet in tweet_data:
#       2     messages = [
#       3         {"role": "system", "content": f"""rewrite the tweets delimited by {delimiter} in the tone like Stewie """},
#       4         {"role": "user", "content": f"{delimiter}{tweet}{delimiter} "}]
# ----> 6     print(openai_help(messages).strip(delimiter))
#
# Cell In[4], line 10, in openai_help(messages, model, temperature)
#       8 def openai_help(messages, model=model, temperature =temperature ):
#       9     messages = messages
# ---> 10     response = client.chat.completions.create(
#      11         model=model,
#      12         messages=messages,
#      13         temperature=temperature
#      14
#      15     )
#      16     return response.choices[0].message.content
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/openai/_utils/_utils.py:279, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     277             msg = f"Missing required argument: {quote(missing[0])}"
#     278     raise TypeError(msg)
# --> 279 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/openai/resources/chat/completions/completions.py:914, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, web_search_options, extra_headers, extra_query, extra_body, timeout)
#     871 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     872 def create(
#     873     self,
#    (...)
#     911     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     912 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     913     validate_response_format(response_format)
# --> 914     return self._post(
#     915         "/chat/completions",
#     916         body=maybe_transform(
#     917             {
#     918                 "messages": messages,
#     919                 "model": model,
#     920                 "audio": audio,
#     921                 "frequency_penalty": frequency_penalty,
#     922                 "function_call": function_call,
#     923                 "functions": functions,
#     924                 "logit_bias": logit_bias,
#     925                 "logprobs": logprobs,
#     926                 "max_completion_tokens": max_completion_tokens,
#     927                 "max_tokens": max_tokens,
#     928                 "metadata": metadata,
#     929                 "modalities": modalities,
#     930                 "n": n,
#     931                 "parallel_tool_calls": parallel_tool_calls,
#     932                 "prediction": prediction,
#     933                 "presence_penalty": presence_penalty,
#     934                 "reasoning_effort": reasoning_effort,
#     935                 "response_format": response_format,
#     936                 "seed": seed,
#     937                 "service_tier": service_tier,
#     938                 "stop": stop,
#     939                 "store": store,
#     940                 "stream": stream,
#     941                 "stream_options": stream_options,
#     942                 "temperature": temperature,
#     943                 "tool_choice": tool_choice,
#     944                 "tools": tools,
#     945                 "top_logprobs": top_logprobs,
#     946                 "top_p": top_p,
#     947                 "user": user,
#     948                 "web_search_options": web_search_options,
#     949             },
#     950             completion_create_params.CompletionCreateParams,
#     951         ),
#     952         options=make_request_options(
#     953             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     954         ),
#     955         cast_to=ChatCompletion,
#     956         stream=stream or False,
#     957         stream_cls=Stream[ChatCompletionChunk],
#     958     )
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/openai/_base_client.py:1242, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1228 def post(
#    1229     self,
#    1230     path: str,
#    (...)
#    1237     stream_cls: type[_StreamT] | None = None,
#    1238 ) -> ResponseT | _StreamT:
#    1239     opts = FinalRequestOptions.construct(
#    1240         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1241     )
# -> 1242     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/openai/_base_client.py:919, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     916 else:
#     917     retries_taken = 0
# --> 919 return self._request(
#     920     cast_to=cast_to,
#     921     options=options,
#     922     stream=stream,
#     923     stream_cls=stream_cls,
#     924     retries_taken=retries_taken,
#     925 )
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/openai/_base_client.py:955, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     952 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     954 try:
# --> 955     response = self._client.send(
#     956         request,
#     957         stream=stream or self._should_stream_response_body(request=request),
#     958         **kwargs,
#     959     )
#     960 except httpx.TimeoutException as err:
#     961     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File ~/anaconda3/envs/python3/lib/python3.10/ssl.py:1292, in SSLSocket.recv(self, buflen, flags)
#    1288     if flags != 0:
#    1289         raise ValueError(
#    1290             "non-zero flags not allowed in calls to recv() on %s" %
#    1291             self.__class__)
# -> 1292     return self.read(buflen)
#    1293 else:
#    1294     return super().recv(buflen, flags)
#
# File ~/anaconda3/envs/python3/lib/python3.10/ssl.py:1165, in SSLSocket.read(self, len, buffer)
#    1163         return self._sslobj.read(len, buffer)
#    1164     else:
# -> 1165         return self._sslobj.read(len)
#    1166 except SSLError as x:
#    1167     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Inferring
# - Use step-by-step instructions with delimiters to:
#   1. Identify sentiments
#   2. Identify emotions
#   3. Extract mentioned people's names
#   3. Identify whether a tweet supports Democratic, Republican, or unknown
#   4. Extract outputs into a structured JSON document.
# - Identify topics from Tweets.

# %%
for tweet in tweet_data:
    messages = [
        {"role": "system", "content": f"""analyze the tweet delimited by {delimiter} in the following steps:
                                        step 1 {delimiter} identify the tweet sentiment in a single word, either positive, negative or neutral;
                                        step 2 {delimiter} identify the emotions expressed in the tweet with a single word;
                                        step 3 {delimiter} extract the mentioned peoples;
                                        step 4 {delimiter} detect whether the tweet support Democratic or Replublican, return the resunt in a single word;
                                        step 5 {delimiter} organize the result in a json document with the keys <sentiment>, <emontion>,<mentioned>, <support>
                                         Do not wrap the json codes in JSON markers and only return the json document"""},
        {"role": "user", "content": f"{delimiter}{tweet}{delimiter} "}]
    print(openai_help(messages))
# Out:
# {
#   "sentiment": "negative",
#   "emotion": "concern",
#   "mentioned": [],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "fear",
#   "mentioned": ["Kamala"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "determination",
#   "mentioned": ["ssecijak"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["Glenn Youngkin"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "concern",
#   "mentioned": ["newrepublic", "Rasmussen Reports", "Trump"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": [
#     "NickGarzilli",
#     "BruneElections",
#     "SMCosta6",
#     "tencor_7144"
#   ],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "concern",
#   "mentioned": [],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "skepticism",
#   "mentioned": ["PATRICKHENRY97"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["Trump", "FBI"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "curiosity",
#   "mentioned": ["Eknath Shinde", "Uddhav Thackeray", "India Today"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "speculative",
#   "mentioned": ["Donald Trump"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "skepticism",
#   "mentioned": ["@EndWokeness"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "caution",
#   "mentioned": ["Craptld2kids"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "anxious",
#   "mentioned": ["django"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Greg St"],
#   "support": "neutral"
# }
# {
#   "sentiment": "positive",
#   "emotion": "satisfaction",
#   "mentioned": ["OccupyDemocrats"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "suspicion",
#   "mentioned": ["VigilantFox"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "anger",
#   "mentioned": ["LauraLoomer"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "humiliation",
#   "mentioned": ["Donald Trump"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": [
#     "BretBaier",
#     "President Biden",
#     "Trump"
#   ],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "sarcasm",
#   "mentioned": [],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["@DustieDahl", "@KathleenWinche3"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "determination",
#   "mentioned": ["MargieVotes"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["whstancil"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "outrage",
#   "mentioned": ["FBI", "Trump"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "caution",
#   "mentioned": ["SimonWDC", "Polymarket", "Elon"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "determination",
#   "mentioned": ["@joshtheobald3"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "anticipation",
#   "mentioned": ["Trump"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "curiosity",
#   "mentioned": ["ScottPresler", "Thad Hall"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": [
#     "@CentristMadness"
#   ],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["Biden", "Harris"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "curiosity",
#   "mentioned": ["dYdX", "Trump"],
#   "support": "Republican"
# }
# {
#   "sentiment": "positive",
#   "emotion": "hopeful",
#   "mentioned": [],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "sarcasm",
#   "mentioned": ["MarioNawfal"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["DanRShafer", "Tammy Baldwin", "Uihleins"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["@C_Farthammer"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "indifferent",
#   "mentioned": ["Bupendra Hooda", "Sharad Pawar"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "criticism",
#   "mentioned": ["themarketswork", "Kamala"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "seriousness",
#   "mentioned": ["BradBeauregardJ"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "anticipation",
#   "mentioned": ["Donald Trump"],
#   "support": "Republican"
# }
# {
#   "sentiment": "positive",
#   "emotion": "pride",
#   "mentioned": [],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "skepticism",
#   "mentioned": ["@christianboutin", "@scrowder"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "concern",
#   "mentioned": ["michaelsbarajas"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "outrage",
#   "mentioned": ["RealMattCouch", "Trump"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "shock",
#   "mentioned": ["SimonWDC", "Trump"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["FrankLuntz", "NPR", "Donald Trump"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["maddenifico"],
#   "support": "Republican"
# }
# {
#   "sentiment": "positive",
#   "emotion": "excitement",
#   "mentioned": ["Trump"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["LibertyLockPod"],
#   "support": "Republican"
# }
# {
#   "sentiment": "positive",
#   "emotion": "satisfaction",
#   "mentioned": ["Kamala Harris", "Trump"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "positive",
#   "emotion": "concern",
#   "mentioned": ["mtgreenee"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": [],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["@realDonaldTrump"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "cynicism",
#   "mentioned": ["shaun_vids", "netanyahu"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "hopeful",
#   "mentioned": ["CristusVictor"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "frustration",
#   "mentioned": ["MTGrepp"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["RonFilipkowski"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Lucas_FCGB"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "criticism",
#   "mentioned": ["NickJFuentes", "Trump"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "disapproval",
#   "mentioned": [
#     "GeoffDuncanGA",
#     "Donald Trump"
#   ],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "anger",
#   "mentioned": ["Donald Trump"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "anxiety",
#   "mentioned": ["mariashriver", "KamalaHarris"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": [],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["Starboy2079"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "understanding",
#   "mentioned": [
#     "@glassfire77",
#     "@0xMikado"
#   ],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "anger",
#   "mentioned": ["mrddmia"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": [
#     "BehizyTweets"
#   ],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "concern",
#   "mentioned": ["nancyd1957", "sdduba"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "inclusive",
#   "mentioned": ["ScottPresler", "RFK Jr."],
#   "support": "Republican"
# }
# {
#   "sentiment": "positive",
#   "emotion": "excitement",
#   "mentioned": ["Donald Trump"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["BrendanKeefe", "ATLNewsFirst"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "urgency",
#   "mentioned": ["AmazingZoltan"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["DefiyantlyFree"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["ecomarxi"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "concern",
#   "mentioned": ["ghn_news"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "concern",
#   "mentioned": [],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "curiosity",
#   "mentioned": ["GuntherEagleman"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["EdanClay"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "anger",
#   "mentioned": ["James Comer", "TheRickyDavila"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "defiance",
#   "mentioned": ["Barack Obama", "WesleyHuntTX"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "curiosity",
#   "mentioned": [
#     "@onelerv",
#     "@z388z",
#     "@EricLDaugh"
#   ],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "seriousness",
#   "mentioned": ["BradBeauregardJ"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "determined",
#   "mentioned": ["levparnas", "rea"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["BehizyTweets"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "anger",
#   "mentioned": ["LangmanVince", "BretBaier", "VP"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Real_RobN"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "curiosity",
#   "mentioned": ["Joe Rogan", "Kamala Harris"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["TristanSnell"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["TristanSnell"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": [
#     "ChristruthJ",
#     "Real_RobN"
#   ],
#   "support": "Republican"
# }
# {
#   "sentiment": "positive",
#   "emotion": "excitement",
#   "mentioned": ["MichelleObama", "WhenWeAllVote"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "indifference",
#   "mentioned": [],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "anticipation",
#   "mentioned": ["hodgetwins", "Trump"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "concern",
#   "mentioned": [
#     "Abbas Alawieh"
#   ],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["MJTruthUltra"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "determination",
#   "mentioned": ["Conservative_BC"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "confusion",
#   "mentioned": ["Morning_Joe"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["Joe Rogan", "Kamala Harris"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Rep. Mark Pocan", "StephMillerShow"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["JoyceWhiteVance"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "determination",
#   "mentioned": ["KamalaHarris"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["@libsoftiktok", "@DavidMuir"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["MacFarlaneNews", "Jimmy Carter", "Carter Center"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["Donald Trump"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "concern",
#   "mentioned": ["WarrenCoDemsOH"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["LongTimeHistory"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "anticipation",
#   "mentioned": ["argosaki"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "determination",
#   "mentioned": ["mjfree"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "disdain",
#   "mentioned": ["Mike Johnson", "Trump"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "anticipation",
#   "mentioned": [],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "confusion",
#   "mentioned": ["Morning_Joe"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Rajiv Kumar"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "duty",
#   "mentioned": ["JackPosobiec"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["MZHemingway"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "concern",
#   "mentioned": ["Donald Trump"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "suspicion",
#   "mentioned": ["CollinRugg", "Joy Reid"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "outrage",
#   "mentioned": ["LauraLoomer"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "surprise",
#   "mentioned": ["PanditSaibpal", "Abhay Dubey"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "anticipation",
#   "mentioned": ["julie_kelly2", "Kamala"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "mocking",
#   "mentioned": ["@scrowder"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "negative",
#   "emotion": "disapproval",
#   "mentioned": [
#     "BrandtRobinson",
#     "TheClassicPhil"
#   ],
#   "support": "Democratic"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "determination",
#   "mentioned": ["mjfree"],
#   "support": "neutral"
# }
# {
#   "sentiment": "negative",
#   "emotion": "suspicion",
#   "mentioned": ["Norm Eisen", "Michael Chertoff"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "anger",
#   "mentioned": ["AndrewPatriot_"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "anticipation",
#   "mentioned": ["BillieJeanKing"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "anticipation",
#   "mentioned": ["ecomarxi"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["Donald Trump"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "curiosity",
#   "mentioned": ["@I_Am_Legion_73", "@wires44", "@IsabellaMDeLuca"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "disapproval",
#   "mentioned": ["krassenstein"],
#   "support": "Democratic"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "anticipation",
#   "mentioned": ["nypost"],
#   "support": "neutral"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "informative",
#   "mentioned": ["DanRShafer"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "anticipation",
#   "mentioned": [
#     "PeterHRatcliffe",
#     "CPC_HQ",
#     "Pierre Poilievre",
#     "JustinTrudeau"
#   ],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "anticipation",
#   "mentioned": ["JesseBWatters", "KamalaHarris"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "distrust",
#   "mentioned": ["ScottAdamsSays", "Trump"],
#   "support": "Republican"
# }
# {
#   "sentiment": "neutral",
#   "emotion": "inclusive",
#   "mentioned": ["ScottPresler", "RFK Jr."],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "concern",
#   "mentioned": ["GuntherEagleman"],
#   "support": "Republican"
# }
# {
#   "sentiment": "negative",
#   "emotion": "frustration",
#   "mentioned": ["Mark Robinson", "CNN"],
#   "support": "Republican"
# }
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 11
#       1 for tweet in tweet_data:
#       2     messages = [
#       3         {"role": "system", "content": f"""analyze the tweet delimited by {delimiter} in the following steps:
#       4                                         step 1 {delimiter} identify the tweet sentiment in a single word, either positive, negative or neutral;
#    (...)
#       9                                          Do not wrap the json codes in JSON markers and only return the json document"""},
#      10         {"role": "user", "content": f"{delimiter}{tweet}{delimiter} "}]
# ---> 11     print(openai_help(messages))
#
# Cell In[4], line 10, in openai_help(messages, model, temperature)
#       8 def openai_help(messages, model=model, temperature =temperature ):
#       9     messages = messages
# ---> 10     response = client.chat.completions.create(
#      11         model=model,
#      12         messages=messages,
#      13         temperature=temperature
#      14
#      15     )
#      16     return response.choices[0].message.content
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/openai/_utils/_utils.py:279, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     277             msg = f"Missing required argument: {quote(missing[0])}"
#     278     raise TypeError(msg)
# --> 279 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/openai/resources/chat/completions/completions.py:914, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, web_search_options, extra_headers, extra_query, extra_body, timeout)
#     871 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     872 def create(
#     873     self,
#    (...)
#     911     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     912 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     913     validate_response_format(response_format)
# --> 914     return self._post(
#     915         "/chat/completions",
#     916         body=maybe_transform(
#     917             {
#     918                 "messages": messages,
#     919                 "model": model,
#     920                 "audio": audio,
#     921                 "frequency_penalty": frequency_penalty,
#     922                 "function_call": function_call,
#     923                 "functions": functions,
#     924                 "logit_bias": logit_bias,
#     925                 "logprobs": logprobs,
#     926                 "max_completion_tokens": max_completion_tokens,
#     927                 "max_tokens": max_tokens,
#     928                 "metadata": metadata,
#     929                 "modalities": modalities,
#     930                 "n": n,
#     931                 "parallel_tool_calls": parallel_tool_calls,
#     932                 "prediction": prediction,
#     933                 "presence_penalty": presence_penalty,
#     934                 "reasoning_effort": reasoning_effort,
#     935                 "response_format": response_format,
#     936                 "seed": seed,
#     937                 "service_tier": service_tier,
#     938                 "stop": stop,
#     939                 "store": store,
#     940                 "stream": stream,
#     941                 "stream_options": stream_options,
#     942                 "temperature": temperature,
#     943                 "tool_choice": tool_choice,
#     944                 "tools": tools,
#     945                 "top_logprobs": top_logprobs,
#     946                 "top_p": top_p,
#     947                 "user": user,
#     948                 "web_search_options": web_search_options,
#     949             },
#     950             completion_create_params.CompletionCreateParams,
#     951         ),
#     952         options=make_request_options(
#     953             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     954         ),
#     955         cast_to=ChatCompletion,
#     956         stream=stream or False,
#     957         stream_cls=Stream[ChatCompletionChunk],
#     958     )
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/openai/_base_client.py:1242, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1228 def post(
#    1229     self,
#    1230     path: str,
#    (...)
#    1237     stream_cls: type[_StreamT] | None = None,
#    1238 ) -> ResponseT | _StreamT:
#    1239     opts = FinalRequestOptions.construct(
#    1240         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1241     )
# -> 1242     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/openai/_base_client.py:919, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     916 else:
#     917     retries_taken = 0
# --> 919 return self._request(
#     920     cast_to=cast_to,
#     921     options=options,
#     922     stream=stream,
#     923     stream_cls=stream_cls,
#     924     retries_taken=retries_taken,
#     925 )
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/openai/_base_client.py:955, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     952 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     954 try:
# --> 955     response = self._client.send(
#     956         request,
#     957         stream=stream or self._should_stream_response_body(request=request),
#     958         **kwargs,
#     959     )
#     960 except httpx.TimeoutException as err:
#     961     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File ~/anaconda3/envs/python3/lib/python3.10/ssl.py:1292, in SSLSocket.recv(self, buflen, flags)
#    1288     if flags != 0:
#    1289         raise ValueError(
#    1290             "non-zero flags not allowed in calls to recv() on %s" %
#    1291             self.__class__)
# -> 1292     return self.read(buflen)
#    1293 else:
#    1294     return super().recv(buflen, flags)
#
# File ~/anaconda3/envs/python3/lib/python3.10/ssl.py:1165, in SSLSocket.read(self, len, buffer)
#    1163         return self._sslobj.read(len, buffer)
#    1164     else:
# -> 1165         return self._sslobj.read(len)
#    1166 except SSLError as x:
#    1167     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
messages = [
        {"role": "system", "content": f"""analyze the tweet delimited by {delimiter} to identify 10 topics, 
                                  Do not wrap the json codes in JSON markers """},
        {"role": "user", "content": f"{delimiter}{tweet_data}{delimiter} "}]
print(openai_help(messages))
# Out:
# {
#   "topics": [
#     "Election Interference and Fraud Allegations",
#     "Voting and Voter Registration Issues",
#     "Media and Election Coverage",
#     "Political Campaigns and Strategies",
#     "Election Laws and Legal Challenges",
#     "Public Sentiment and Polling",
#     "International Relations and Foreign Influence",
#     "Cryptocurrency and Market Reactions",
#     "Political Figures and Their Influence",
#     "Social Media and Misinformation"
#   ]
# }

# %% [markdown]
# ### Expanding with multiple prompts
# - Identify which party receives majority supports
# - Provide contexts in the system message
# - Create a chatbot to answer users’ inquiry

# %%
analysis_result = []
from tqdm import tqdm
for tweet in tqdm(tweet_data):
    messages = [
        {"role": "system", "content": f"""analyze the tweet delimited by {delimiter} in the following steps:
                                        step 1 {delimiter} identify the tweet sentiment in a single word, either positive, negative or neutral;
                                        step 2 {delimiter} identify the emotions expressed in the tweet with a single word;
                                        step 3 {delimiter} extract the mentioned peoples;
                                        step 4 {delimiter} detect whether the tweet support Democratic or Replublican, return the resunt in a singple word;
                                        step 5 {delimiter} organize the result in a json document with the keys <sentiment>, <emontion>,<mentioned>, <support>
                                         Do not wrap the json codes in JSON markers and only return the json document"""},
        {"role": "user", "content": f"{delimiter}{tweet}{delimiter} "}]
    analysis_result.append(openai_help(messages))
# Out:
# 100%|██████████| 299/299 [04:40<00:00,  1.07it/s]

# %%
print(analysis_result)
# Out:
# ['{\n  "sentiment": "negative",\n  "emotion": "concern",\n  "mentioned": [],\n  "support": "Democratic"\n}', '{\n  "sentiment": "negative",\n  "emotion": "fear",\n  "mentioned": ["Kamala"],\n  "support": "Republican"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "determination",\n  "mentioned": ["ssecijak"],\n  "support": "Democratic"\n}', '{\n  "sentiment": "negative",\n  "emotion": "frustration",\n  "mentioned": ["GlennYoungkin"],\n  "support": "Republican"\n}', '{\n  "sentiment": "negative",\n  "emotion": "concern",\n  "mentioned": ["newrepublic", "Rasmussen Reports", "Trump"],\n  "support": "Democratic"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "concern",\n  "mentioned": [\n    "NickGarzilli",\n    "BruneElections",\n    "SMCosta6",\n    "tencor_7144"\n  ],\n  "support": "neutral"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "concern",\n  "mentioned": [],\n  "support": "Democratic"\n}', '{\n  "sentiment": "negative",\n  "emotion": "skepticism",\n  "mentioned": ["PATRICKHENRY97"],\n  "support": "Republican"\n}', '{\n  "sentiment": "negative",\n  "emotion": "frustration",\n  "mentioned": ["Trump", "FBI"],\n  "support": "Republican"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "curiosity",\n  "mentioned": ["Eknath Shinde", "Uddhav Thackeray", "India Today"],\n  "support": "neutral"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "speculative",\n  "mentioned": ["Donald Trump"],\n  "support": "Republican"\n}', '{\n  "sentiment": "negative",\n  "emotion": "skepticism",\n  "mentioned": ["@EndWokeness"],\n  "support": "Republican"\n}', '{\n  "sentiment": "negative",\n  "emotion": "caution",\n  "mentioned": ["Craptld2kids"],\n  "support": "Republican"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "anxious",\n  "mentioned": ["django"],\n  "support": "neutral"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "informative",\n  "mentioned": ["Greg St"],\n  "support": "neutral"\n}', '{\n  "sentiment": "positive",\n  "emotion": "satisfaction",\n  "mentioned": ["OccupyDemocrats"],\n  "support": "Democratic"\n}', '{\n  "sentiment": "negative",\n  "emotion": "suspicion",\n  "mentioned": ["VigilantFox"],\n  "support": "Republican"\n}', '{\n  "sentiment": "negative",\n  "emotion": "anger",\n  "mentioned": ["LauraLoomer", "Trump"],\n  "support": "Republican"\n}', '{\n  "sentiment": "negative",\n  "emotion": "humiliation",\n  "mentioned": ["Donald Trump"],\n  "support": "Democratic"\n}', '{\n  "sentiment": "negative",\n  "emotion": "frustration",\n  "mentioned": ["BretBaier"],\n  "support": "Republican"\n}', '{\n  "sentiment": "negative",\n  "emotion": "sarcasm",\n  "mentioned": [],\n  "support": "neutral"\n}', '{\n  "sentiment": "negative",\n  "emotion": "frustration",\n  "mentioned": ["@DustieDahl", "@KathleenWinche3"],\n  "support": "Republican"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "determination",\n  "mentioned": ["MargieVotes"],\n  "support": "Democratic"\n}', '{\n  "sentiment": "negative",\n  "emotion": "frustration",\n  "mentioned": ["whstancil"],\n  "support": "Democratic"\n}', '{ "sentiment": "negative", "emotion": "outrage", "mentioned": ["Trump"], "support": "Republican" }', '{\n  "sentiment": "neutral",\n  "emotion": "awareness",\n  "mentioned": ["SimonWDC", "Polymarket", "Elon"],\n  "support": "Republican"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "informative",\n  "mentioned": ["@joshtheobald3"],\n  "support": "neutral"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "anticipation",\n  "mentioned": [],\n  "support": "Republican"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "curiosity",\n  "mentioned": [\n    "ScottPresler",\n    "Thad Hall"\n  ],\n  "support": "Republican"\n}', '{\n  "sentiment": "negative",\n  "emotion": "frustration",\n  "mentioned": ["@CentristMadness"],\n  "support": "neutral"\n}', '{\n  "sentiment": "negative",\n  "emotion": "frustration",\n  "mentioned": ["Biden", "Harris"],\n  "support": "Democratic"\n}', '{\n  "sentiment": "neutral",\n  "emotion": "curiosity",\ ...

# %%
messages = [
        {"role": "system", "content": f"""analyze the tweet analysis reuslt delimited by {delimiter} in the following steps:
                                        step 1 {delimiter} count the number of tweets that support Democratic and Republican;
                                        step 2 {delimiter} identify the common sentiments and emotoions to each mentioned people;
                                        step 3 {delimiter} organize the result in a json document with keys <Democratic count>, <Republican count>, <people name>
                                         Do not wrap the json codes in JSON markers and only return the json document"""},
        {"role": "user", "content": f"{delimiter}{analysis_result}{delimiter} "}]
analysis_summary = openai_help(messages)
print(analysis_summary)
# Out:
# {
#   "Democratic count": 30,
#   "Republican count": 80,
#   "people name": {
#     "Democratic": {
#       "common sentiments": ["negative", "neutral", "positive"],
#       "common emotions": ["frustration", "concern", "anger", "admiration", "supportive"]
#     },
#     "Republican": {
#       "common sentiments": ["negative", "neutral", "positive"],
#       "common emotions": ["frustration", "anger", "concern", "informative", "anticipation"]
#     }
#   }
# }

# %% [markdown]
# ## Create a chatbot

# %%
from openai import OpenAI

openai_api_key  = get_secret('openai')['api_key']
client = OpenAI(api_key=openai_api_key)
model = 'gpt-4o'
temperature = 0

chat_history = [

{"role": "system", "content": f"""you are a chabot answer user questions based on the tweets,
                                {delimiter}{tweet_data}{delimiter}, 
                                if user mentioned a people name in the {delimiter}{analysis_summary}{delimiter} people field,report the corresponding sentiment and emotion,
                            
                            """}
]

def chatbot(prompt):

    chat_history.append({"role": "user", "content": prompt})

    response = client.chat.completions.create(
        model=model,  # Use the model you prefer
        messages=chat_history
    )

    reply = response.choices[0].message.content

    chat_history.append({"role": "assistant", "content": reply})
    
    return reply

# %%
while True:
    user_input = input("You: ")
    if user_input.lower() in ['exit', 'quit']:
        print("Chatbot: Goodbye!")
        break
    reply = chatbot(user_input)
    print(f"Chatbot: {reply}")
# Out:
# You:  what are they talking about?

# %% [markdown]
# ## Reference
# - Isa Fulford and Andrew Ng. n.d.-a. *“Building Systems with the ChatGPT API.”* DeepLearning.AI. Accessed October 25, 2024. https://www.deeplearning.ai/short-courses/building-systems-with-chatgpt/.
# - ———. n.d.-b. *“ChatGPT Prompt Engineering for Developers.”* DeepLearning.AI. Accessed October 25, 2024. https://www.deeplearning.ai/short-courses/chatgpt-prompt-engineering-for-developers/.
# - OpenAI. n.d. *“OpenAI Documents.”* OpenAI. Accessed October 18, 2024. https://platform.openai.com.
